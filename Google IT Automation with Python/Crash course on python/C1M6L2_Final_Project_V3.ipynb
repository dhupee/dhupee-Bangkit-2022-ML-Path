# %% [markdown]
# # Final Project - Word Cloud

# %% [markdown]
# For this project, you'll create a "word cloud" from a text by writing a script.  This script needs to process the text, remove punctuation, ignore case and words that do not contain all alphabets, count the frequencies, and ignore uninteresting or irrelevant words.  A dictionary is the output of the `calculate_frequencies` function.  The `wordcloud` module will then generate the image from your dictionary.

# %% [markdown]
# For the input text of your script, you will need to provide a file that contains text only.  For the text itself, you can copy and paste the contents of a website you like.  Or you can use a site like [Project Gutenberg](https://www.gutenberg.org/) to find books that are available online.  You could see what word clouds you can get from famous books, like a Shakespeare play or a novel by Jane Austen. Save this as a .txt file somewhere on your computer.
# <br><br>
# Now you will need to upload your input file here so that your script will be able to process it.  To do the upload, you will need an uploader widget.  Run the following cell to perform all the installs and imports for your word cloud script and uploader widget.  It may take a minute for all of this to run and there will be a lot of output messages. But, be patient. Once you get the following final line of output, the code is done executing. Then you can continue on with the rest of the instructions for this notebook.
# <br><br>
# **Enabling notebook extension fileupload/extension...**
# <br>
# **- Validating: <font color =green>OK</font>**

# %%
# Here are all the installs and imports you will need for your word cloud script and uploader widget

# !pip install wordcloud
# !pip install fileupload
# !pip install ipywidgets
# !jupyter nbextension install --py --user fileupload
# !jupyter nbextension enable --py fileupload

import wordcloud
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display
import fileupload
import io
import sys
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.1-cp38-cp38-win_amd64.whl (155 kB)
# Requirement already satisfied: matplotlib in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from wordcloud) (9.0.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from wordcloud) (1.22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from matplotlib->wordcloud) (4.28.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from matplotlib->wordcloud) (3.0.6)
# Requirement already satisfied: six>=1.5 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.1
# Collecting fileupload
#   Downloading fileupload-0.1.5-py2.py3-none-any.whl (6.2 kB)
# Requirement already satisfied: traitlets>=4.2 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from fileupload) (5.1.1)
# Collecting ipywidgets>=5.1
#   Downloading ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
# Collecting notebook>=4.2
#   Downloading notebook-6.4.8-py3-none-any.whl (9.9 MB)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipywidgets>=5.1->fileupload) (7.29.0)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.2-py2.py3-none-any.whl (1.6 MB)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.2-py3-none-any.whl (243 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipywidgets>=5.1->fileupload) (6.4.1)
# Collecting nbformat>=4.2.0
#   Downloading nbformat-5.1.3-py3-none-any.whl (178 kB)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipywidgets>=5.1->fileupload) (0.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (7.1.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.1.2)
# Requirement already satisfied: pygments in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (2.10.0)
# Requirement already satisfied: pickleshare in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.7.5)
# Requirement already satisfied: colorama in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.4.4)
# Requirement already satisfied: decorator in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (3.0.20)
# Requirement already satisfied: backcall in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (4.9.1)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (1.5.1)
# Requirement already satisfied: entrypoints in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (0.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (302)
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading jsonschema-4.4.0-py3-none-any.whl (72 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp38-cp38-win_amd64.whl (61 kB)
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.4.0-py3-none-any.whl (28 kB)
# Collecting zipp>=3.1.0
#   Downloading zipp-3.7.0-py3-none-any.whl (5.3 kB)
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting jinja2
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting nbconvert
#   Downloading nbconvert-6.4.2-py3-none-any.whl (558 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.13.1-py3-none-any.whl (57 kB)
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.13.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: wcwidth in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=5.1->fileupload) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=5.1->fileupload) (1.16.0)
# Collecting pywinpty>=1.1.0
#   Downloading pywinpty-2.0.2-cp38-none-win_amd64.whl (1.4 MB)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Collecting cffi>=1.0.1
#   Downloading cffi-1.15.0-cp38-cp38-win_amd64.whl (179 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.0-cp38-cp38-win_amd64.whl (16 kB)
# Collecting testpath
#   Downloading testpath-0.5.0-py3-none-any.whl (84 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting bleach
#   Downloading bleach-4.1.0-py2.py3-none-any.whl (157 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading nbclient-0.5.11-py3-none-any.whl (71 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: packaging in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from bleach->nbconvert->notebook>=4.2->fileupload) (21.3)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.2->fileupload) (3.0.6)
# Installing collected packages: zipp, pyrsistent, importlib-resources, attrs, pycparser, jsonschema, webencodings, nbformat, MarkupSafe, cffi, testpath, pywinpty, pandocfilters, nbclient, mistune, jupyterlab-pygments, jinja2, defusedxml, bleach, argon2-cffi-bindings, terminado, Send2Trash, prometheus-client, nbconvert, argon2-cffi, notebook, widgetsnbextension, jupyterlab-widgets, ipywidgets, fileupload
# Successfully installed MarkupSafe-2.1.0 Send2Trash-1.8.0 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 attrs-21.4.0 bleach-4.1.0 cffi-1.15.0 defusedxml-0.7.1 fileupload-0.1.5 importlib-resources-5.4.0 ipywidgets-7.6.5 jinja2-3.0.3 jsonschema-4.4.0 jupyterlab-pygments-0.1.2 jupyterlab-widgets-1.0.2 mistune-0.8.4 nbclient-0.5.11 nbconvert-6.4.2 nbformat-5.1.3 notebook-6.4.8 pandocfilters-1.5.0 prometheus-client-0.13.1 pycparser-2.21 pyrsistent-0.18.1 pywinpty-2.0.2 terminado-0.13.1 testpath-0.5.0 webencodings-0.5.1 widgetsnbextension-3.5.2 zipp-3.7.0
# Requirement already satisfied: ipywidgets in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (7.6.5)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipywidgets) (7.29.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipywidgets) (6.4.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: pygments in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.10.0)
# Requirement already satisfied: pickleshare in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: decorator in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.0)
# Requirement already satisfied: colorama in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: backcall in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (302)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (5.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (3.7.0)
# Requirement already satisfied: wcwidth in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.8)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: nbconvert in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.4.2)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.1.0)
# Requirement already satisfied: bleach in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.11)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: testpath in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: webencodings in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\arya wijna\anaconda3\envs\dh-env\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.6)
# Installing C:\Users\Arya Wijna\anaconda3\envs\DH-env\lib\site-packages\fileupload\static -> fileupload
# Making directory: C:\Users\Arya Wijna\AppData\Roaming\jupyter\nbextensions\fileupload\
# Copying: C:\Users\Arya Wijna\anaconda3\envs\DH-env\lib\site-packages\fileupload\static\extension.js -> C:\Users\Arya Wijna\AppData\Roaming\jupyter\nbextensions\fileupload\extension.js
# Copying: C:\Users\Arya Wijna\anaconda3\envs\DH-env\lib\site-packages\fileupload\static\widget.js -> C:\Users\Arya Wijna\AppData\Roaming\jupyter\nbextensions\fileupload\widget.js
# Making directory: C:\Users\Arya Wijna\AppData\Roaming\jupyter\nbextensions\fileupload\fileupload
# Copying: C:\Users\Arya Wijna\anaconda3\envs\DH-env\lib\site-packages\fileupload\static\fileupload\widget.js -> C:\Users\Arya Wijna\AppData\Roaming\jupyter\nbextensions\fileupload\fileupload\widget.js
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable fileupload --user --py
#
# Enabling notebook extension fileupload/extension...
#       - Validating: ok

# %% [markdown]
# Whew! That was a lot. All of the installs and imports for your word cloud script and uploader widget have been completed.
# <br><br>
# **IMPORTANT!** If this was your first time running the above cell containing the installs and imports, you will need save this notebook now. Then under the File menu above,  select Close and Halt. When the notebook has completely shut down, reopen it. This is the only way the necessary changes will take affect.
# <br><br>
# To upload your text file, run the following cell that contains all the code for a custom uploader widget. Once you run this cell, a "Browse" button should appear below it. Click this button and navigate the window to locate your saved text file.

# %%
# This is the uploader widget

def _upload():

    _upload_widget = fileupload.FileUploadWidget()

    def _cb(change):
        global file_contents
        decoded = io.StringIO(change['owner'].data.decode('utf-8'))
        filename = change['owner'].filename
        print('Uploaded `{}` ({:.2f} kB)'.format(
            filename, len(decoded.read()) / 2 **10))
        file_contents = decoded.getvalue()

    _upload_widget.observe(_cb, names='data')
    display(_upload_widget)

_upload()
# Out:
# FileUploadWidget(label='Browse', _dom_classes=('widget_item', 'btn-group'))

# %% [markdown]
# The uploader widget saved the contents of your uploaded file into a string object named *file_contents* that your word cloud script can process. This was a lot of preliminary work, but you are now ready to begin your script.

# %% [markdown]
# Write a function in the cell below that iterates through the words in *file_contents*, removes punctuation, and counts the frequency of each word.  Oh, and be sure to make it ignore word case, words that do not contain all alphabets and boring words like "and" or "the".  Then use it in the `generate_from_frequencies` function to generate your very own word cloud!
# <br><br>
# **Hint:** Try storing the results of your iteration in a dictionary before passing them into wordcloud via the `generate_from_frequencies` function.

# %%
file_contents = 'weird_text.txt' # directory

# %%
def calculate_frequencies(file_contents):
    # Here is a list of punctuations and uninteresting words you can use to process your text
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    uninteresting_words = ["the", "a", "to", "if", "is", "it", "of", "and", "or", "an", "as", "i", "me", "my", \
    "we", "our", "ours", "you", "your", "yours", "he", "she", "him", "his", "her", "hers", "its", "they", "them", \
    "their", "what", "which", "who", "whom", "this", "that", "am", "are", "was", "were", "be", "been", "being", \
    "have", "has", "had", "do", "does", "did", "but", "at", "by", "with", "from", "here", "when", "where", "how", \
    "all", "any", "both", "each", "few", "more", "some", "such", "no", "nor", "too", "very", "can", "will", "just"]

    # LEARNER CODE START HERE

    # turn txt file into a string
    with open(file_contents, 'r') as f: 
        text = f.read()
    words = text

    # split the file_contents into words
    words = words.split()
    print(words, '\n')
    
    # remove punctuations from list
    new_words = []
    for word in words:
        for letter in word:
            if letter in punctuations:
                word = word.replace(letter,"")   
        new_words.append(word)
    print(new_words, '\n')

    # remove uninteresting words from list
    new_words = [word for word in new_words if word not in uninteresting_words]
    print(new_words, '\n')

    # capitalize words in list
    new_words = [word.capitalize() for word in new_words]

    # count the frequency of each word
    word_count = {}
    for word in new_words:
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1
    print(word_count, '\n')
        
    #wordcloud
    cloud = wordcloud.WordCloud()
    cloud.generate_from_frequencies(word_count)
    return cloud.to_array()

# %% [markdown]
# If you have done everything correctly, your word cloud image should appear after running the cell below.  Fingers crossed!

# %%
# Display your wordcloud image

myimage = calculate_frequencies(file_contents)
plt.imshow(myimage, interpolation = 'nearest')
plt.axis('off')
plt.show()
# Out:
# ['Glasses', 'are', 'really', 'versatile.', 'First,', 'you', 'can', 'have', 'glasses-wearing', 'girls', 'take', 'them', 'off', 'and', 'suddenly', 'become', 'beautiful,', 'or', 'have', 'girls', 'wearing', 'glasses', 'flashing', 'those', 'cute', 'grins,', 'or', 'have', 'girls', 'stealing', 'the', "protagonist's", 'glasses', 'and', 'putting', 'them', 'on', 'like,', '"Haha,', 'got', 'your', 'glasses!"', "That's", 'just', 'way', 'too', 'cute!', 'Also,', 'boys', 'with', 'glasses!', 'I', 'really', 'like', 'when', 'their', 'glasses', 'have', 'that', 'suspicious', 'looking', 'gleam,', 'and', "it's", 'amazing', 'how', 'it', 'can', 'look', 'really', 'cool', 'or', 'just', 'be', 'a', 'joke.', 'I', 'really', 'like', 'how', 'it', 'can', 'fulfill', 'all', 'those', 'abstract', 'needs.', 'Being', 'able', 'to', 'switch', 'up', 'the', 'styles', 'and', 'colors', 'of', 'glasses', 'based', 'on', 'your', 'mood', 'is', 'a', 'lot', 'of', 'fun', 'too!', "It's", 'actually', 'so', 'much', 'fun!', 'You', 'have', 'those', 'half', 'rim', 'glasses,', 'or', 'the', 'thick', 'frame', 'glasses,', 'everything!', "It's", 'like', "you're", 'enjoying', 'all', 'these', 'kinds', 'of', 'glasses', 'at', 'a', 'buffet.', 'I', 'really', 'want', 'Luna', 'to', 'try', 'some', 'on', 'or', 'Marine', 'to', 'try', 'some', 'on', 'to', 'replace', 'her', 'eyepatch.', 'We', 'really', 'need', 'glasses', 'to', 'become', 'a', 'thing', 'in', 'hololive', 'and', 'start', 'selling', 'them', 'for', 'HoloComi.', "Don't.", 'You.', 'Think.', 'We.', 'Really.', 'Need.', 'To.', 'Officially.', 'Give.', 'Everyone.', 'Glasses?']
#
# ['Glasses', 'are', 'really', 'versatile', 'First', 'you', 'can', 'have', 'glasseswearing', 'girls', 'take', 'them', 'off', 'and', 'suddenly', 'become', 'beautiful', 'or', 'have', 'girls', 'wearing', 'glasses', 'flashing', 'those', 'cute', 'grins', 'or', 'have', 'girls', 'stealing', 'the', 'protagonists', 'glasses', 'and', 'putting', 'them', 'on', 'like', 'Haha', 'got', 'your', 'glasses', 'Thats', 'just', 'way', 'too', 'cute', 'Also', 'boys', 'with', 'glasses', 'I', 'really', 'like', 'when', 'their', 'glasses', 'have', 'that', 'suspicious', 'looking', 'gleam', 'and', 'its', 'amazing', 'how', 'it', 'can', 'look', 'really', 'cool', 'or', 'just', 'be', 'a', 'joke', 'I', 'really', 'like', 'how', 'it', 'can', 'fulfill', 'all', 'those', 'abstract', 'needs', 'Being', 'able', 'to', 'switch', 'up', 'the', 'styles', 'and', 'colors', 'of', 'glasses', 'based', 'on', 'your', 'mood', 'is', 'a', 'lot', 'of', 'fun', 'too', 'Its', 'actually', 'so', 'much', 'fun', 'You', 'have', 'those', 'half', 'rim', 'glasses', 'or', 'the', 'thick', 'frame', 'glasses', 'everything', 'Its', 'like', 'youre', 'enjoying', 'all', 'these', 'kinds', 'of', 'glasses', 'at', 'a', 'buffet', 'I', 'really', 'want', 'Luna', 'to', 'try', 'some', 'on', 'or', 'Marine', 'to', 'try', 'some', 'on', 'to', 'replace', 'her', 'eyepatch', 'We', 'really', 'need', 'glasses', 'to', 'become', 'a', 'thing', 'in', 'hololive', 'and', 'start', 'selling', 'them', 'for', 'HoloComi', 'Dont', 'You', 'Think', 'We', 'Really', 'Need', 'To', 'Officially', 'Give', 'Everyone', 'Glasses']
#
# ['Glasses', 'really', 'versatile', 'First', 'glasseswearing', 'girls', 'take', 'off', 'suddenly', 'become', 'beautiful', 'girls', 'wearing', 'glasses', 'flashing', 'those', 'cute', 'grins', 'girls', 'stealing', 'protagonists', 'glasses', 'putting', 'on', 'like', 'Haha', 'got', 'glasses', 'Thats', 'way', 'cute', 'Also', 'boys', 'glasses', 'I', 'really', 'like', 'glasses', 'suspicious', 'looking', 'gleam', 'amazing', 'look', 'really', 'cool', 'joke', 'I', 'really', 'like', 'fulfill', 'those', 'abstract', 'needs', 'Being', 'able', 'switch', 'up', 'styles', 'colors', 'glasses', 'based', 'on', 'mood', 'lot', 'fun', 'Its', 'actually', 'so', 'much', 'fun', 'You', 'those', 'half', 'rim', 'glasses', 'thick', 'frame', 'glasses', 'everything', 'Its', 'like', 'youre', 'enjoying', 'these', 'kinds', 'glasses', 'buffet', 'I', 'really', 'want', 'Luna', 'try', 'on', 'Marine', 'try', 'on', 'replace', 'eyepatch', 'We', 'really', 'need', 'glasses', 'become', 'thing', 'in', 'hololive', 'start', 'selling', 'for', 'HoloComi', 'Dont', 'You', 'Think', 'We', 'Really', 'Need', 'To', 'Officially', 'Give', 'Everyone', 'Glasses']
#
# {'Glasses': 12, 'Really': 7, 'Versatile': 1, 'First': 1, 'Glasseswearing': 1, 'Girls': 3, 'Take': 1, 'Off': 1, 'Suddenly': 1, 'Become': 2, 'Beautiful': 1, 'Wearing': 1, 'Flashing': 1, 'Those': 3, 'Cute': 2, 'Grins': 1, 'Stealing': 1, 'Protagonists': 1, 'Putting': 1, 'On': 4, 'Like': 4, 'Haha': 1, 'Got': 1, 'Thats': 1, 'Way': 1, 'Also': 1, 'Boys': 1, 'I': 3, 'Suspicious': 1, 'Looking': 1, 'Gleam': 1, 'Amazing': 1, 'Look': 1, 'Cool': 1, 'Joke': 1, 'Fulfill': 1, 'Abstract': 1, 'Needs': 1, 'Being': 1, 'Able': 1, 'Switch': 1, 'Up': 1, 'Styles': 1, 'Colors': 1, 'Based': 1, 'Mood': 1, 'Lot': 1, 'Fun': 2, 'Its': 2, 'Actually': 1, 'So': 1, 'Much': 1, 'You': 2, 'Half': 1, 'Rim': 1, 'Thick': 1, 'Frame': 1, 'Everything': 1, 'Youre': 1, 'Enjoying': 1, 'These': 1, 'Kinds': 1, 'Buffet': 1, 'Want': 1, 'Luna': 1, 'Try': 2, 'Marine': 1, 'Replace': 1, 'Eyepatch': 1, 'We': 2, 'Need': 2, 'Thing': 1, 'In': 1, 'Hololive': 1, 'Start': 1, 'Selling': 1, 'For': 1, 'Holocomi': 1, 'Dont': 1, 'Think': 1, 'To': 1, 'Officially': 1, 'Give': 1, 'Everyone': 1}

# %% [markdown]
# If your word cloud image did not appear, go back and rework your `calculate_frequencies` function until you get the desired output.  Definitely check that you passed your frequecy count dictionary into the `generate_from_frequencies` function of `wordcloud`. Once you have correctly displayed your word cloud image, you are all done with this project. Nice work!
