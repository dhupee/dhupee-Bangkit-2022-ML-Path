# %% [markdown]
# # Week 2: Diving deeper into the BBC News archive
#
# Welcome! In this assignment you will be revisiting the [BBC News Classification Dataset](https://www.kaggle.com/c/learn-ai-bbc/overview), which contains 2225 examples of news articles with their respective labels.
#
# This time you will not only work with the tokenization process but you will also create a classifier using specialized layers for text data such as Embedding and GlobalAveragePooling1D.
#
# Let's get started!

# %%
import io
import csv
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# %% [markdown]
# You probably remember structure of the csv that contains the data from last week, but in case you need a reminder run the next cell:

# %%
with open("./bbc-text.csv", 'r') as csvfile:
    print(f"First line (header) looks like this:\n\n{csvfile.readline()}")
    print(f"Each data point looks like this:\n\n{csvfile.readline()}")
# Out:
# First line (header) looks like this:
#
# category,text
#
# Each data point looks like this:
#
# tech,tv future in the hands of viewers with home theatre systems  plasma high-definition tvs  and digital video recorders moving into the living room  the way people watch tv will be radically different in five years  time.  that is according to an expert panel which gathered at the annual consumer electronics show in las vegas to discuss how these new technologies will impact one of our favourite pastimes. with the us leading the trend  programmes and other content will be delivered to viewers via home networks  through cable  satellite  telecoms companies  and broadband service providers to front rooms and portable devices.  one of the most talked-about technologies of ces has been digital and personal video recorders (dvr and pvr). these set-top boxes  like the us s tivo and the uk s sky+ system  allow people to record  store  play  pause and forward wind tv programmes when they want.  essentially  the technology allows for much more personalised tv. they are also being built-in to high-definition tv sets  which are big business in japan and the us  but slower to take off in europe because of the lack of high-definition programming. not only can people forward wind through adverts  they can also forget about abiding by network and channel schedules  putting together their own a-la-carte entertainment. but some us networks and cable and satellite companies are worried about what it means for them in terms of advertising revenues as well as  brand identity  and viewer loyalty to channels. although the us leads in this technology at the moment  it is also a concern that is being raised in europe  particularly with the growing uptake of services like sky+.  what happens here today  we will see in nine months to a years  time in the uk   adam hume  the bbc broadcast s futurologist told the bbc news website. for the likes of the bbc  there are no issues of lost advertising revenue yet. it is a more pressing issue at the moment for commercial uk broadcasters  but brand loyalty is important for everyone.  we will be talking more about content brands rather than network brands   said tim hanlon  from brand communications firm starcom mediavest.  the reality is that with broadband connections  anybody can be the producer of content.  he added:  the challenge now is that it is hard to promote a programme with so much choice.   what this means  said stacey jolna  senior vice president of tv guide tv group  is that the way people find the content they want to watch has to be simplified for tv viewers. it means that networks  in us terms  or channels could take a leaf out of google s book and be the search engine of the future  instead of the scheduler to help people find what they want to watch. this kind of channel model might work for the younger ipod generation which is used to taking control of their gadgets and what they play on them. but it might not suit everyone  the panel recognised. older generations are more comfortable with familiar schedules and channel brands because they know what they are getting. they perhaps do not want so much of the choice put into their hands  mr hanlon suggested.  on the other end  you have the kids just out of diapers who are pushing buttons already - everything is possible and available to them   said mr hanlon.  ultimately  the consumer will tell the market they want.   of the 50 000 new gadgets and technologies being showcased at ces  many of them are about enhancing the tv-watching experience. high-definition tv sets are everywhere and many new models of lcd (liquid crystal display) tvs have been launched with dvr capability built into them  instead of being external boxes. one such example launched at the show is humax s 26-inch lcd tv with an 80-hour tivo dvr and dvd recorder. one of the us s biggest satellite tv companies  directtv  has even launched its own branded dvr at the show with 100-hours of recording capability  instant replay  and a search function. the set can pause and rewind tv ...

# %% [markdown]
# As you can see, each data point is composed of the category of the news article followed by a comma and then the actual text of the article.

# %% [markdown]
# ## Defining useful global variables
#
# Next you will define some global variables that will be used throughout the assignment.
#
# - `NUM_WORDS`: The maximum number of words to keep, based on word frequency. Defaults to 1000.
#
#
# - `EMBEDDING_DIM`: Dimension of the dense embedding, will be used in the embedding layer of the model. Defaults to 16.
#
#
# - `MAXLEN`: Maximum length of all sequences. Defaults to 120.
#
#
# - `PADDING`: Padding strategy (pad either before or after each sequence.). Defaults to 'post'.
#
#
# - `OOV_TOKEN`: Token to replace out-of-vocabulary words during text_to_sequence calls. Defaults to "\<OOV>".
#
#
# - `TRAINING_SPLIT`: Proportion of data used for training. Defaults to 0.8
#
# **For now leave them unchanged but after submitting your assignment for grading you are encouraged to come back here and play with these parameters to see the impact they have in the classification process**

# %%
NUM_WORDS = 1000
EMBEDDING_DIM = 16
MAXLEN = 120
PADDING = 'post'
OOV_TOKEN = "<OOV>"
TRAINING_SPLIT = .8

# %% [markdown]
# ## Loading and pre-processing the data
#
# Now you should code the functions to remove stopwords from text and to load the data from a csv file.
#
# Since you already coded these functions for the previous week, these are provided for you.

# %%
def remove_stopwords(sentence):
    # List of stopwords
    stopwords = ["a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at", "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do", "does", "doing", "down", "during", "each", "few", "for", "from", "further", "had", "has", "have", "having", "he", "he'd", "he'll", "he's", "her", "here", "here's", "hers", "herself", "him", "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", "if", "in", "into", "is", "it", "it's", "its", "itself", "let's", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or", "other", "ought", "our", "ours", "ourselves", "out", "over", "own", "same", "she", "she'd", "she'll", "she's", "should", "so", "some", "such", "than", "that", "that's", "the", "their", "theirs", "them", "themselves", "then", "there", "there's", "these", "they", "they'd", "they'll", "they're", "they've", "this", "those", "through", "to", "too", "under", "until", "up", "very", "was", "we", "we'd", "we'll", "we're", "we've", "were", "what", "what's", "when", "when's", "where", "where's", "which", "while", "who", "who's", "whom", "why", "why's", "with", "would", "you", "you'd", "you'll", "you're", "you've", "your", "yours", "yourself", "yourselves" ]
    
    # Sentence converted to lowercase-only
    sentence = sentence.lower()

    words = sentence.split()
    no_words = [w for w in words if w not in stopwords]
    sentence = " ".join(no_words)

    return sentence


def parse_data_from_file(filename):
    sentences = []
    labels = []
    with open(filename, 'r') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        next(reader)
        for row in reader:
            labels.append(row[0])
            sentence = row[1]
            sentence = remove_stopwords(sentence)
            sentences.append(sentence)

    return sentences, labels

# %%
# Test the functions
sentences, labels = parse_data_from_file("./bbc-text.csv")

print(f"There are {len(sentences)} sentences in the dataset.\n")
print(f"First sentence has {len(sentences[0].split())} words (after removing stopwords).\n")
print(f"There are {len(labels)} labels in the dataset.\n")
print(f"The first 5 labels are {labels[:5]}")
# Out:
# There are 2225 sentences in the dataset.
#
# First sentence has 436 words (after removing stopwords).
#
# There are 2225 labels in the dataset.
#
# The first 5 labels are ['tech', 'business', 'sport', 'sport', 'entertainment']

# %% [markdown]
# ***Expected Output:***
#
# ```
# There are 2225 sentences in the dataset.
#
# First sentence has 436 words (after removing stopwords).
#
# There are 2225 labels in the dataset.
#
# The first 5 labels are ['tech', 'business', 'sport', 'sport', 'entertainment']
# ```

# %% [markdown]
# ## Training - Validation Split
#
# Now you will code the `train_val_split`, which given the list of sentences, the list of labels and the proportion of data for the training set, should return the training and validation sentences and labels:

# %%
# GRADED FUNCTIONS: train_val_split
def train_val_split(sentences, labels, training_split):
    
    ### START CODE HERE
    
    # Compute the number of sentences that will be used for training (should be an integer)
    train_size = int(training_split * len(sentences))

    # Split the sentences and labels into train/validation splits
    train_sentences = sentences[:train_size]
    train_labels = labels[:train_size]

    validation_sentences = sentences[train_size:]
    validation_labels = labels[train_size:]
    
    ### END CODE HERE
    
    return train_sentences, validation_sentences, train_labels, validation_labels

# %%
# Test your function
train_sentences, val_sentences, train_labels, val_labels = train_val_split(sentences, labels, TRAINING_SPLIT)

print(f"There are {len(train_sentences)} sentences for training.\n")
print(f"There are {len(train_labels)} labels for training.\n")
print(f"There are {len(val_sentences)} sentences for validation.\n")
print(f"There are {len(val_labels)} labels for validation.")
# Out:
# There are 1780 sentences for training.
#
# There are 1780 labels for training.
#
# There are 445 sentences for validation.
#
# There are 445 labels for validation.

# %% [markdown]
# ***Expected Output:***
#
# ```
# There are 1780 sentences for training.
#
# There are 1780 labels for training.
#
# There are 445 sentences for validation.
#
# There are 445 labels for validation.
# ```

# %% [markdown]
# ## Tokenization - Sequences and padding
#
# Now that you have sets for training and validation it is time for you to begin the tokenization process.
#
# Begin by completing the `fit_tokenizer` function below. This function should return a [Tokenizer](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/text/Tokenizer) that has been fitted to the training sentences.

# %%
# GRADED FUNCTION: fit_tokenizer
def fit_tokenizer(train_sentences, num_words, oov_token):
    
    ### START CODE HERE
    
    # Instantiate the Tokenizer class, passing in the correct values for num_words and oov_token
    tokenizer = Tokenizer(num_words=num_words, oov_token=oov_token)
    
    # Fit the tokenizer to the training sentences
    tokenizer.fit_on_texts(train_sentences)
    
    ### END CODE HERE
    
    return tokenizer

# %%
# Test your function
tokenizer = fit_tokenizer(train_sentences, NUM_WORDS, OOV_TOKEN)
word_index = tokenizer.word_index

print(f"Vocabulary contains {len(word_index)} words\n")
print("<OOV> token included in vocabulary" if "<OOV>" in word_index else "<OOV> token NOT included in vocabulary")
# Out:
# Vocabulary contains 27285 words
#
# <OOV> token included in vocabulary

# %% [markdown]
# ***Expected Output:***
#
# ```
# Vocabulary contains 27285 words
#
# <OOV> token included in vocabulary
# ```

# %% [markdown]
# Now that the tokenizer has been fitted to the training data, you need a function that will convert each text data point into its padded sequence representation, for this complete the `seq_and_pad` function below:

# %%
# GRADED FUNCTION: seq_and_pad
def seq_and_pad(sentences, tokenizer, padding, maxlen):
    
    ### START CODE HERE
    
    # Convert sentences to sequences
    sequences = tokenizer.texts_to_sequences(sentences)
    
    # Pad the sequences using the correct padding and maxlen
    padded_sequences = pad_sequences(sequences, padding=padding, maxlen=maxlen)
    
    ### END CODE HERE
    
    return padded_sequences

# %%
# Test your function
train_padded_seq = seq_and_pad(train_sentences, tokenizer, PADDING, MAXLEN)
val_padded_seq = seq_and_pad(val_sentences, tokenizer, PADDING, MAXLEN)

print(f"Padded training sequences have shape: {train_padded_seq.shape}\n")
print(f"Padded validation sequences have shape: {val_padded_seq.shape}")
# Out:
# Padded training sequences have shape: (1780, 120)
#
# Padded validation sequences have shape: (445, 120)

# %% [markdown]
# ***Expected Output:***
#
# ```
# Padded training sequences have shape: (1780, 120)
#
# Padded validation sequences have shape: (445, 120)
# ```

# %% [markdown]
# Finally you need to tokenize the labels. For this complete the `tokenize_labels` function below.
#
# A couple of things to note:
# - You should fit the tokenizer to all the labels to avoid the case of a particular label not being present in the validation set. Since you are dealing with labels there should never be an OOV label.
#
#
# - In the previous function you used the `pad_sequences` function which returns numpy arrays. Here you will not be using it since you don't need to pad the labels so you need to make the conversion to numpy arrays yourself.
#
#
# - The argument `split_labels` refers to the labels of a particular split (train or validation). This is because the function should work independently of the split being used.
#
#
# - Using Keras' Tokenizer yields values that start at 1 rather than at 0. This will present a problem when training since Keras usually expects the labels to start at 0. To work around this issue you could use an extra neuron in the last layer of your model. However this approach is rather hacky and not very clear. Instead you will substract 1 from every value of the labels that the function returns. Remember that when using numpy arrays you can simply do something like `np.array - 1` to accomplish this since numpy allows for vectorized operations.

# %%
# GRADED FUNCTION: tokenize_labels
def tokenize_labels(all_labels, split_labels):
    
    ### START CODE HERE
    
    # Instantiate the Tokenizer (no additional arguments needed)
    label_tokenizer = Tokenizer()
    
    # Fit the tokenizer on all the labels
    label_tokenizer.fit_on_texts(all_labels)
    
    # Convert labels to sequences
    label_seq = label_tokenizer.texts_to_sequences(split_labels)
    
    # Convert sequences to a numpy array. Don't forget to substact 1 from every entry in the array!
    label_seq_np = np.array(label_seq) - 1
    
    ### END CODE HERE
    
    return label_seq_np

# %%
# Test your function
train_label_seq = tokenize_labels(labels, train_labels)
val_label_seq = tokenize_labels(labels, val_labels)

print(f"First 5 labels of the training set should look like this:\n{train_label_seq[:5]}\n")
print(f"First 5 labels of the validation set should look like this:\n{val_label_seq[:5]}\n")
print(f"Tokenized labels of the training set have shape: {train_label_seq.shape}\n")
print(f"Tokenized labels of the validation set have shape: {val_label_seq.shape}\n")
# Out:
# First 5 labels of the training set should look like this:
# [[3]
#  [1]
#  [0]
#  [0]
#  [4]]
#
# First 5 labels of the validation set should look like this:
# [[4]
#  [3]
#  [2]
#  [0]
#  [0]]
#
# Tokenized labels of the training set have shape: (1780, 1)
#
# Tokenized labels of the validation set have shape: (445, 1)

# %% [markdown]
# ***Expected Output:***
#
# ```
# First 5 labels of the training set should look like this:
# [[3]
#  [1]
#  [0]
#  [0]
#  [4]]
#
# First 5 labels of the validation set should look like this:
# [[4]
#  [3]
#  [2]
#  [0]
#  [0]]
#
# Tokenized labels of the training set have shape: (1780, 1)
#
# Tokenized labels of the validation set have shape: (445, 1)
# ```

# %% [markdown]
# ## Selecting the model for text classification
#
# Now that the data is ready to be fed a Neural Network it is time for you to define the model that will classify each text as being part of a certain category.
#
# For this complete the `create_model` below.
#
# A couple of things to keep in mind:
#
# - Notice that this function has three parameters, all of which are meant to be passed to an [Embedding](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding) layer, which is what you will probably use as a first layer for your model.
#
#
# - The last layer should be a Dense layer with 5 units (since there are 5 categories) with a softmax activation.
#
#
# - You should also compile your model using an appropiate loss function and optimizer.
#
#
# - You can use any architecture you want but keep in mind that this problem doesn't need many layers to be solved successfully. You don't need any layers beside Embedding, [GlobalAveragePooling1D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling1D) and Dense layers but feel free to try out different architectures.
#
#
# - **To pass this graded function your model should reach at least a 95% training accuracy and a 90% validation accuracy in under 30 epochs.**

# %%
# GRADED FUNCTION: create_model
def create_model(num_words, embedding_dim, maxlen):
    
    tf.random.set_seed(123)
    
    ### START CODE HERE
    
    model = tf.keras.Sequential([ 
        tf.keras.layers.Embedding(num_words, embedding_dim, input_length=maxlen),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dense(24, activation='relu'),
        tf.keras.layers.Dense(6, activation='softmax')
    ])
    
    model.compile(
        loss = 'sparse_categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )

    ### END CODE HERE

    return model

# %%
model = create_model(NUM_WORDS, EMBEDDING_DIM, MAXLEN)

history = model.fit(train_padded_seq, train_label_seq, epochs=300, validation_data=(val_padded_seq, val_label_seq))
# Out:
# Epoch 1/300
# 56/56 [==============================] - 0s 3ms/step - loss: 1.7588 - accuracy: 0.2287 - val_loss: 1.7248 - val_accuracy: 0.3551
# Epoch 2/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.6851 - accuracy: 0.3848 - val_loss: 1.6496 - val_accuracy: 0.4562
# Epoch 3/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.6129 - accuracy: 0.3657 - val_loss: 1.5848 - val_accuracy: 0.4337
# Epoch 4/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.5360 - accuracy: 0.4478 - val_loss: 1.4942 - val_accuracy: 0.4584
# Epoch 5/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.4075 - accuracy: 0.4927 - val_loss: 1.3459 - val_accuracy: 0.5146
# Epoch 6/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.2196 - accuracy: 0.5876 - val_loss: 1.1501 - val_accuracy: 0.6562
# Epoch 7/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.9990 - accuracy: 0.7489 - val_loss: 0.9485 - val_accuracy: 0.7843
# Epoch 8/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.8005 - accuracy: 0.8371 - val_loss: 0.7860 - val_accuracy: 0.8360
# Epoch 9/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6470 - accuracy: 0.8848 - val_loss: 0.6641 - val_accuracy: 0.8674
# Epoch 10/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5275 - accuracy: 0.9084 - val_loss: 0.5635 - val_accuracy: 0.8697
# Epoch 11/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4367 - accuracy: 0.9191 - val_loss: 0.4932 - val_accuracy: 0.8876
# Epoch 12/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3671 - accuracy: 0.9298 - val_loss: 0.4363 - val_accuracy: 0.8899
# Epoch 13/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3121 - accuracy: 0.9388 - val_loss: 0.3984 - val_accuracy: 0.8989
# Epoch 14/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2687 - accuracy: 0.9461 - val_loss: 0.3605 - val_accuracy: 0.8989
# Epoch 15/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2340 - accuracy: 0.9534 - val_loss: 0.3307 - val_accuracy: 0.9011
# Epoch 16/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2055 - accuracy: 0.9607 - val_loss: 0.3074 - val_accuracy: 0.9011
# Epoch 17/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1815 - accuracy: 0.9657 - val_loss: 0.2882 - val_accuracy: 0.9079
# Epoch 18/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1616 - accuracy: 0.9713 - val_loss: 0.2799 - val_accuracy: 0.9146
# Epoch 19/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1448 - accuracy: 0.9742 - val_loss: 0.2619 - val_accuracy: 0.9101
# Epoch 20/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1292 - accuracy: 0.9775 - val_loss: 0.2502 - val_accuracy: 0.9236
# Epoch 21/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1175 - accuracy: 0.9798 - val_loss: 0.2457 - val_accuracy: 0.9281
# Epoch 22/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9843 - val_loss: 0.2321 - val_accuracy: 0.9258
# Epoch 23/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0953 - accuracy: 0.9848 - val_loss: 0.2306 - val_accuracy: 0.9258
# Epoch 24/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0867 - accuracy: 0.9888 - val_loss: 0.2202 - val_accuracy: 0.9281
# Epoch 25/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0787 - accuracy: 0.9904 - val_loss: 0.2179 - val_accuracy: 0.9348
# Epoch 26/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9927 - val_loss: 0.2138 - val_accuracy: 0.9348
# Epoch 27/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0653 - accuracy: 0.9949 - val_loss: 0.2153 - val_accuracy: 0.9348
# Epoch 28/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0592 - accuracy: 0.9966 - val_loss: 0.2049 - val_accuracy: 0.9371
# Epoch 29/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9961 - val_loss: 0.2064 - val_accuracy: 0.9348
# Epoch 30/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 0.9966 - val_loss: 0.1983 - val_accuracy: 0.9393
# Epoch 31/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9978 - val_loss: 0.1992 - val_accuracy: 0.9371
# Epoch 32/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9972 - val_loss: 0.1963 - val_accuracy: 0.9371
# Epoch 33/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9978 - val_loss: 0.1945 - val_accuracy: 0.9393
# Epoch 34/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9983 - val_loss: 0.1901 - val_accuracy: 0.9393
# Epoch 35/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0305 - accuracy: 0.9983 - val_loss: 0.1912 - val_accuracy: 0.9416
# Epoch 36/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 0.9989 - val_loss: 0.1902 - val_accuracy: 0.9393
# Epoch 37/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 0.9989 - val_loss: 0.1889 - val_accuracy: 0.9393
# Epoch 38/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 0.9989 - val_loss: 0.1884 - val_accuracy: 0.9416
# Epoch 39/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9994 - val_loss: 0.1867 - val_accuracy: 0.9416
# Epoch 40/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9994 - val_loss: 0.1879 - val_accuracy: 0.9393
# Epoch 41/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.9994 - val_loss: 0.1870 - val_accuracy: 0.9416
# Epoch 42/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.1868 - val_accuracy: 0.9416
# Epoch 43/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.1871 - val_accuracy: 0.9393
# Epoch 44/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.9416
# Epoch 45/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.1868 - val_accuracy: 0.9393
# Epoch 46/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.1872 - val_accuracy: 0.9393
# Epoch 47/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.1869 - val_accuracy: 0.9393
# Epoch 48/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.1868 - val_accuracy: 0.9393
# Epoch 49/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.1874 - val_accuracy: 0.9393
# Epoch 50/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.1879 - val_accuracy: 0.9393
# Epoch 51/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9416
# Epoch 52/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9438
# Epoch 53/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.1884 - val_accuracy: 0.9393
# Epoch 54/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9438
# Epoch 55/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9438
# Epoch 56/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9416
# Epoch 57/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1906 - val_accuracy: 0.9461
# Epoch 58/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9438
# Epoch 59/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1908 - val_accuracy: 0.9461
# Epoch 60/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9438
# Epoch 61/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9461
# Epoch 62/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9461
# Epoch 63/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9461
# Epoch 64/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9461
# Epoch 65/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1941 - val_accuracy: 0.9461
# Epoch 66/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1947 - val_accuracy: 0.9461
# Epoch 67/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1949 - val_accuracy: 0.9461
# Epoch 68/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1955 - val_accuracy: 0.9461
# Epoch 69/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 0.9461
# Epoch 70/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9461
# Epoch 71/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1964 - val_accuracy: 0.9461
# Epoch 72/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9461
# Epoch 73/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9461
# Epoch 74/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9461
# Epoch 75/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9461
# Epoch 76/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9461
# Epoch 77/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2005 - val_accuracy: 0.9461
# Epoch 78/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9461
# Epoch 79/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9461
# Epoch 80/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2020 - val_accuracy: 0.9461
# Epoch 81/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2021 - val_accuracy: 0.9461
# Epoch 82/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9461
# Epoch 83/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9461
# Epoch 84/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9461
# Epoch 85/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9461
# Epoch 86/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9461
# Epoch 87/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9461
# Epoch 88/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9461
# Epoch 89/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2064 - val_accuracy: 0.9461
# Epoch 90/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9461
# Epoch 91/300
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9461
# Epoch 92/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.9275e-04 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9461
# Epoch 93/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.4990e-04 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9461
# Epoch 94/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.1066e-04 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9461
# Epoch 95/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.7352e-04 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9461
# Epoch 96/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.3778e-04 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9461
# Epoch 97/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.0420e-04 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9461
# Epoch 98/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.7298e-04 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9461
# Epoch 99/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.4164e-04 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9461
# Epoch 100/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.1023e-04 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9461
# Epoch 101/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.8175e-04 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9461
# Epoch 102/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.5410e-04 - accuracy: 1.0000 - val_loss: 0.2136 - val_accuracy: 0.9461
# Epoch 103/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.3041e-04 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9461
# Epoch 104/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.0433e-04 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.9461
# Epoch 105/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.8089e-04 - accuracy: 1.0000 - val_loss: 0.2153 - val_accuracy: 0.9461
# Epoch 106/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.5865e-04 - accuracy: 1.0000 - val_loss: 0.2154 - val_accuracy: 0.9461
# Epoch 107/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.3573e-04 - accuracy: 1.0000 - val_loss: 0.2166 - val_accuracy: 0.9461
# Epoch 108/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.1748e-04 - accuracy: 1.0000 - val_loss: 0.2172 - val_accuracy: 0.9461
# Epoch 109/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.9496e-04 - accuracy: 1.0000 - val_loss: 0.2175 - val_accuracy: 0.9461
# Epoch 110/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.7686e-04 - accuracy: 1.0000 - val_loss: 0.2181 - val_accuracy: 0.9461
# Epoch 111/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.5861e-04 - accuracy: 1.0000 - val_loss: 0.2186 - val_accuracy: 0.9461
# Epoch 112/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.4147e-04 - accuracy: 1.0000 - val_loss: 0.2191 - val_accuracy: 0.9461
# Epoch 113/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.2411e-04 - accuracy: 1.0000 - val_loss: 0.2197 - val_accuracy: 0.9461
# Epoch 114/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.0832e-04 - accuracy: 1.0000 - val_loss: 0.2204 - val_accuracy: 0.9461
# Epoch 115/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.9467e-04 - accuracy: 1.0000 - val_loss: 0.2208 - val_accuracy: 0.9461
# Epoch 116/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.7928e-04 - accuracy: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9461
# Epoch 117/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.6439e-04 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9461
# Epoch 118/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.5072e-04 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9461
# Epoch 119/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.3840e-04 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9483
# Epoch 120/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.2575e-04 - accuracy: 1.0000 - val_loss: 0.2238 - val_accuracy: 0.9483
# Epoch 121/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.1392e-04 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9483
# Epoch 122/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.0227e-04 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9483
# Epoch 123/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.9112e-04 - accuracy: 1.0000 - val_loss: 0.2253 - val_accuracy: 0.9483
# Epoch 124/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.8057e-04 - accuracy: 1.0000 - val_loss: 0.2257 - val_accuracy: 0.9483
# Epoch 125/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.7054e-04 - accuracy: 1.0000 - val_loss: 0.2260 - val_accuracy: 0.9483
# Epoch 126/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.6056e-04 - accuracy: 1.0000 - val_loss: 0.2271 - val_accuracy: 0.9483
# Epoch 127/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.5154e-04 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9483
# Epoch 128/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.4240e-04 - accuracy: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.9506
# Epoch 129/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.3394e-04 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9528
# Epoch 130/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.2538e-04 - accuracy: 1.0000 - val_loss: 0.2292 - val_accuracy: 0.9506
# Epoch 131/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.1728e-04 - accuracy: 1.0000 - val_loss: 0.2296 - val_accuracy: 0.9506
# Epoch 132/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.0936e-04 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9483
# Epoch 133/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.0198e-04 - accuracy: 1.0000 - val_loss: 0.2309 - val_accuracy: 0.9506
# Epoch 134/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.9504e-04 - accuracy: 1.0000 - val_loss: 0.2312 - val_accuracy: 0.9528
# Epoch 135/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.8796e-04 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.9528
# Epoch 136/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.8120e-04 - accuracy: 1.0000 - val_loss: 0.2327 - val_accuracy: 0.9506
# Epoch 137/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.7506e-04 - accuracy: 1.0000 - val_loss: 0.2331 - val_accuracy: 0.9506
# Epoch 138/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.6895e-04 - accuracy: 1.0000 - val_loss: 0.2337 - val_accuracy: 0.9506
# Epoch 139/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.6282e-04 - accuracy: 1.0000 - val_loss: 0.2342 - val_accuracy: 0.9528
# Epoch 140/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.5724e-04 - accuracy: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.9506
# Epoch 141/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.5159e-04 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.9528
# Epoch 142/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.4683e-04 - accuracy: 1.0000 - val_loss: 0.2360 - val_accuracy: 0.9528
# Epoch 143/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.4153e-04 - accuracy: 1.0000 - val_loss: 0.2365 - val_accuracy: 0.9528
# Epoch 144/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.3666e-04 - accuracy: 1.0000 - val_loss: 0.2372 - val_accuracy: 0.9528
# Epoch 145/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.3171e-04 - accuracy: 1.0000 - val_loss: 0.2378 - val_accuracy: 0.9528
# Epoch 146/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.2746e-04 - accuracy: 1.0000 - val_loss: 0.2382 - val_accuracy: 0.9528
# Epoch 147/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.2294e-04 - accuracy: 1.0000 - val_loss: 0.2389 - val_accuracy: 0.9528
# Epoch 148/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1869e-04 - accuracy: 1.0000 - val_loss: 0.2395 - val_accuracy: 0.9528
# Epoch 149/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1458e-04 - accuracy: 1.0000 - val_loss: 0.2399 - val_accuracy: 0.9528
# Epoch 150/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1067e-04 - accuracy: 1.0000 - val_loss: 0.2403 - val_accuracy: 0.9528
# Epoch 151/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0681e-04 - accuracy: 1.0000 - val_loss: 0.2411 - val_accuracy: 0.9528
# Epoch 152/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0325e-04 - accuracy: 1.0000 - val_loss: 0.2414 - val_accuracy: 0.9528
# Epoch 153/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.9727e-05 - accuracy: 1.0000 - val_loss: 0.2426 - val_accuracy: 0.9528
# Epoch 154/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.6292e-05 - accuracy: 1.0000 - val_loss: 0.2426 - val_accuracy: 0.9528
# Epoch 155/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.3260e-05 - accuracy: 1.0000 - val_loss: 0.2434 - val_accuracy: 0.9528
# Epoch 156/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.9964e-05 - accuracy: 1.0000 - val_loss: 0.2438 - val_accuracy: 0.9528
# Epoch 157/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.6849e-05 - accuracy: 1.0000 - val_loss: 0.2447 - val_accuracy: 0.9528
# Epoch 158/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.3874e-05 - accuracy: 1.0000 - val_loss: 0.2451 - val_accuracy: 0.9528
# Epoch 159/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.1115e-05 - accuracy: 1.0000 - val_loss: 0.2456 - val_accuracy: 0.9528
# Epoch 160/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.8440e-05 - accuracy: 1.0000 - val_loss: 0.2461 - val_accuracy: 0.9528
# Epoch 161/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.5786e-05 - accuracy: 1.0000 - val_loss: 0.2466 - val_accuracy: 0.9551
# Epoch 162/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.3298e-05 - accuracy: 1.0000 - val_loss: 0.2473 - val_accuracy: 0.9551
# Epoch 163/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.0860e-05 - accuracy: 1.0000 - val_loss: 0.2479 - val_accuracy: 0.9551
# Epoch 164/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.8424e-05 - accuracy: 1.0000 - val_loss: 0.2486 - val_accuracy: 0.9551
# Epoch 165/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.6084e-05 - accuracy: 1.0000 - val_loss: 0.2491 - val_accuracy: 0.9551
# Epoch 166/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.3925e-05 - accuracy: 1.0000 - val_loss: 0.2498 - val_accuracy: 0.9551
# Epoch 167/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.1949e-05 - accuracy: 1.0000 - val_loss: 0.2502 - val_accuracy: 0.9551
# Epoch 168/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.9729e-05 - accuracy: 1.0000 - val_loss: 0.2509 - val_accuracy: 0.9551
# Epoch 169/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.7822e-05 - accuracy: 1.0000 - val_loss: 0.2513 - val_accuracy: 0.9551
# Epoch 170/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.5860e-05 - accuracy: 1.0000 - val_loss: 0.2521 - val_accuracy: 0.9551
# Epoch 171/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.3982e-05 - accuracy: 1.0000 - val_loss: 0.2525 - val_accuracy: 0.9551
# Epoch 172/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.2195e-05 - accuracy: 1.0000 - val_loss: 0.2531 - val_accuracy: 0.9551
# Epoch 173/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.0506e-05 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.9551
# Epoch 174/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.8871e-05 - accuracy: 1.0000 - val_loss: 0.2542 - val_accuracy: 0.9551
# Epoch 175/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.7220e-05 - accuracy: 1.0000 - val_loss: 0.2550 - val_accuracy: 0.9551
# Epoch 176/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.5685e-05 - accuracy: 1.0000 - val_loss: 0.2552 - val_accuracy: 0.9551
# Epoch 177/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.4144e-05 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9551
# Epoch 178/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.2728e-05 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9551
# Epoch 179/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.1323e-05 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9551
# Epoch 180/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.9950e-05 - accuracy: 1.0000 - val_loss: 0.2578 - val_accuracy: 0.9551
# Epoch 181/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.8634e-05 - accuracy: 1.0000 - val_loss: 0.2583 - val_accuracy: 0.9551
# Epoch 182/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.7399e-05 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9551
# Epoch 183/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.6162e-05 - accuracy: 1.0000 - val_loss: 0.2593 - val_accuracy: 0.9551
# Epoch 184/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.4965e-05 - accuracy: 1.0000 - val_loss: 0.2602 - val_accuracy: 0.9551
# Epoch 185/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.3781e-05 - accuracy: 1.0000 - val_loss: 0.2605 - val_accuracy: 0.9551
# Epoch 186/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.2742e-05 - accuracy: 1.0000 - val_loss: 0.2613 - val_accuracy: 0.9551
# Epoch 187/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.1616e-05 - accuracy: 1.0000 - val_loss: 0.2617 - val_accuracy: 0.9551
# Epoch 188/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.0635e-05 - accuracy: 1.0000 - val_loss: 0.2621 - val_accuracy: 0.9551
# Epoch 189/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.9709e-05 - accuracy: 1.0000 - val_loss: 0.2628 - val_accuracy: 0.9551
# Epoch 190/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.8690e-05 - accuracy: 1.0000 - val_loss: 0.2634 - val_accuracy: 0.9551
# Epoch 191/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.7792e-05 - accuracy: 1.0000 - val_loss: 0.2640 - val_accuracy: 0.9551
# Epoch 192/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.6845e-05 - accuracy: 1.0000 - val_loss: 0.2647 - val_accuracy: 0.9551
# Epoch 193/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.5979e-05 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9551
# Epoch 194/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.5151e-05 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9551
# Epoch 195/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.4336e-05 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9551
# Epoch 196/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.3561e-05 - accuracy: 1.0000 - val_loss: 0.2668 - val_accuracy: 0.9551
# Epoch 197/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.2803e-05 - accuracy: 1.0000 - val_loss: 0.2677 - val_accuracy: 0.9551
# Epoch 198/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.2051e-05 - accuracy: 1.0000 - val_loss: 0.2681 - val_accuracy: 0.9551
# Epoch 199/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.1329e-05 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9551
# Epoch 200/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.0705e-05 - accuracy: 1.0000 - val_loss: 0.2695 - val_accuracy: 0.9551
# Epoch 201/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.9991e-05 - accuracy: 1.0000 - val_loss: 0.2700 - val_accuracy: 0.9551
# Epoch 202/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.9352e-05 - accuracy: 1.0000 - val_loss: 0.2706 - val_accuracy: 0.9551
# Epoch 203/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.8757e-05 - accuracy: 1.0000 - val_loss: 0.2712 - val_accuracy: 0.9551
# Epoch 204/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.8127e-05 - accuracy: 1.0000 - val_loss: 0.2717 - val_accuracy: 0.9551
# Epoch 205/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.7572e-05 - accuracy: 1.0000 - val_loss: 0.2723 - val_accuracy: 0.9551
# Epoch 206/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.6997e-05 - accuracy: 1.0000 - val_loss: 0.2731 - val_accuracy: 0.9551
# Epoch 207/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.6469e-05 - accuracy: 1.0000 - val_loss: 0.2737 - val_accuracy: 0.9551
# Epoch 208/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.5944e-05 - accuracy: 1.0000 - val_loss: 0.2742 - val_accuracy: 0.9551
# Epoch 209/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.5457e-05 - accuracy: 1.0000 - val_loss: 0.2746 - val_accuracy: 0.9551
# Epoch 210/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.4924e-05 - accuracy: 1.0000 - val_loss: 0.2753 - val_accuracy: 0.9551
# Epoch 211/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.4470e-05 - accuracy: 1.0000 - val_loss: 0.2759 - val_accuracy: 0.9551
# Epoch 212/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.3999e-05 - accuracy: 1.0000 - val_loss: 0.2766 - val_accuracy: 0.9551
# Epoch 213/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.3559e-05 - accuracy: 1.0000 - val_loss: 0.2770 - val_accuracy: 0.9551
# Epoch 214/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.3128e-05 - accuracy: 1.0000 - val_loss: 0.2776 - val_accuracy: 0.9551
# Epoch 215/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.2728e-05 - accuracy: 1.0000 - val_loss: 0.2782 - val_accuracy: 0.9551
# Epoch 216/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.2321e-05 - accuracy: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.9551
# Epoch 217/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1929e-05 - accuracy: 1.0000 - val_loss: 0.2794 - val_accuracy: 0.9551
# Epoch 218/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1547e-05 - accuracy: 1.0000 - val_loss: 0.2801 - val_accuracy: 0.9551
# Epoch 219/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1186e-05 - accuracy: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.9551
# Epoch 220/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0836e-05 - accuracy: 1.0000 - val_loss: 0.2809 - val_accuracy: 0.9551
# Epoch 221/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0475e-05 - accuracy: 1.0000 - val_loss: 0.2818 - val_accuracy: 0.9551
# Epoch 222/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0153e-05 - accuracy: 1.0000 - val_loss: 0.2826 - val_accuracy: 0.9551
# Epoch 223/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.8359e-06 - accuracy: 1.0000 - val_loss: 0.2829 - val_accuracy: 0.9551
# Epoch 224/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.5339e-06 - accuracy: 1.0000 - val_loss: 0.2836 - val_accuracy: 0.9551
# Epoch 225/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.2405e-06 - accuracy: 1.0000 - val_loss: 0.2841 - val_accuracy: 0.9551
# Epoch 226/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.9341e-06 - accuracy: 1.0000 - val_loss: 0.2849 - val_accuracy: 0.9551
# Epoch 227/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.6752e-06 - accuracy: 1.0000 - val_loss: 0.2856 - val_accuracy: 0.9551
# Epoch 228/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.3889e-06 - accuracy: 1.0000 - val_loss: 0.2860 - val_accuracy: 0.9551
# Epoch 229/300
# 56/56 [==============================] - 0s 2ms/step - loss: 8.1281e-06 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9551
# Epoch 230/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.8868e-06 - accuracy: 1.0000 - val_loss: 0.2870 - val_accuracy: 0.9551
# Epoch 231/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.6282e-06 - accuracy: 1.0000 - val_loss: 0.2879 - val_accuracy: 0.9551
# Epoch 232/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.3888e-06 - accuracy: 1.0000 - val_loss: 0.2884 - val_accuracy: 0.9551
# Epoch 233/300
# 56/56 [==============================] - 0s 2ms/step - loss: 7.1613e-06 - accuracy: 1.0000 - val_loss: 0.2891 - val_accuracy: 0.9551
# Epoch 234/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.9433e-06 - accuracy: 1.0000 - val_loss: 0.2896 - val_accuracy: 0.9551
# Epoch 235/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.7298e-06 - accuracy: 1.0000 - val_loss: 0.2902 - val_accuracy: 0.9551
# Epoch 236/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.5197e-06 - accuracy: 1.0000 - val_loss: 0.2908 - val_accuracy: 0.9551
# Epoch 237/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.3189e-06 - accuracy: 1.0000 - val_loss: 0.2914 - val_accuracy: 0.9551
# Epoch 238/300
# 56/56 [==============================] - 0s 2ms/step - loss: 6.1195e-06 - accuracy: 1.0000 - val_loss: 0.2922 - val_accuracy: 0.9551
# Epoch 239/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.9347e-06 - accuracy: 1.0000 - val_loss: 0.2928 - val_accuracy: 0.9551
# Epoch 240/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.7496e-06 - accuracy: 1.0000 - val_loss: 0.2932 - val_accuracy: 0.9551
# Epoch 241/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.5661e-06 - accuracy: 1.0000 - val_loss: 0.2937 - val_accuracy: 0.9551
# Epoch 242/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.3978e-06 - accuracy: 1.0000 - val_loss: 0.2943 - val_accuracy: 0.9551
# Epoch 243/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.2280e-06 - accuracy: 1.0000 - val_loss: 0.2948 - val_accuracy: 0.9551
# Epoch 244/300
# 56/56 [==============================] - 0s 2ms/step - loss: 5.0760e-06 - accuracy: 1.0000 - val_loss: 0.2957 - val_accuracy: 0.9551
# Epoch 245/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.9130e-06 - accuracy: 1.0000 - val_loss: 0.2962 - val_accuracy: 0.9551
# Epoch 246/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.7650e-06 - accuracy: 1.0000 - val_loss: 0.2967 - val_accuracy: 0.9551
# Epoch 247/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.6192e-06 - accuracy: 1.0000 - val_loss: 0.2974 - val_accuracy: 0.9551
# Epoch 248/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.4716e-06 - accuracy: 1.0000 - val_loss: 0.2978 - val_accuracy: 0.9551
# Epoch 249/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.3321e-06 - accuracy: 1.0000 - val_loss: 0.2986 - val_accuracy: 0.9551
# Epoch 250/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.2161e-06 - accuracy: 1.0000 - val_loss: 0.2992 - val_accuracy: 0.9551
# Epoch 251/300
# 56/56 [==============================] - 0s 2ms/step - loss: 4.0761e-06 - accuracy: 1.0000 - val_loss: 0.3001 - val_accuracy: 0.9551
# Epoch 252/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.9448e-06 - accuracy: 1.0000 - val_loss: 0.3004 - val_accuracy: 0.9551
# Epoch 253/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.8280e-06 - accuracy: 1.0000 - val_loss: 0.3011 - val_accuracy: 0.9551
# Epoch 254/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.7040e-06 - accuracy: 1.0000 - val_loss: 0.3017 - val_accuracy: 0.9551
# Epoch 255/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.5943e-06 - accuracy: 1.0000 - val_loss: 0.3020 - val_accuracy: 0.9551
# Epoch 256/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.4851e-06 - accuracy: 1.0000 - val_loss: 0.3025 - val_accuracy: 0.9551
# Epoch 257/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.3850e-06 - accuracy: 1.0000 - val_loss: 0.3033 - val_accuracy: 0.9551
# Epoch 258/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.2793e-06 - accuracy: 1.0000 - val_loss: 0.3039 - val_accuracy: 0.9551
# Epoch 259/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.1798e-06 - accuracy: 1.0000 - val_loss: 0.3046 - val_accuracy: 0.9551
# Epoch 260/300
# 56/56 [==============================] - 0s 2ms/step - loss: 3.0806e-06 - accuracy: 1.0000 - val_loss: 0.3052 - val_accuracy: 0.9551
# Epoch 261/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.9893e-06 - accuracy: 1.0000 - val_loss: 0.3058 - val_accuracy: 0.9551
# Epoch 262/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.8998e-06 - accuracy: 1.0000 - val_loss: 0.3062 - val_accuracy: 0.9551
# Epoch 263/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.8123e-06 - accuracy: 1.0000 - val_loss: 0.3071 - val_accuracy: 0.9551
# Epoch 264/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.7245e-06 - accuracy: 1.0000 - val_loss: 0.3077 - val_accuracy: 0.9551
# Epoch 265/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.6455e-06 - accuracy: 1.0000 - val_loss: 0.3081 - val_accuracy: 0.9551
# Epoch 266/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.5671e-06 - accuracy: 1.0000 - val_loss: 0.3085 - val_accuracy: 0.9551
# Epoch 267/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.4872e-06 - accuracy: 1.0000 - val_loss: 0.3094 - val_accuracy: 0.9551
# Epoch 268/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.4160e-06 - accuracy: 1.0000 - val_loss: 0.3103 - val_accuracy: 0.9551
# Epoch 269/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.3429e-06 - accuracy: 1.0000 - val_loss: 0.3107 - val_accuracy: 0.9551
# Epoch 270/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.2704e-06 - accuracy: 1.0000 - val_loss: 0.3112 - val_accuracy: 0.9551
# Epoch 271/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.2020e-06 - accuracy: 1.0000 - val_loss: 0.3121 - val_accuracy: 0.9551
# Epoch 272/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.1324e-06 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9551
# Epoch 273/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.0714e-06 - accuracy: 1.0000 - val_loss: 0.3130 - val_accuracy: 0.9551
# Epoch 274/300
# 56/56 [==============================] - 0s 2ms/step - loss: 2.0083e-06 - accuracy: 1.0000 - val_loss: 0.3137 - val_accuracy: 0.9551
# Epoch 275/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.9509e-06 - accuracy: 1.0000 - val_loss: 0.3142 - val_accuracy: 0.9551
# Epoch 276/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.8911e-06 - accuracy: 1.0000 - val_loss: 0.3148 - val_accuracy: 0.9551
# Epoch 277/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.8380e-06 - accuracy: 1.0000 - val_loss: 0.3156 - val_accuracy: 0.9551
# Epoch 278/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.7786e-06 - accuracy: 1.0000 - val_loss: 0.3158 - val_accuracy: 0.9551
# Epoch 279/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.7278e-06 - accuracy: 1.0000 - val_loss: 0.3165 - val_accuracy: 0.9551
# Epoch 280/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.6760e-06 - accuracy: 1.0000 - val_loss: 0.3168 - val_accuracy: 0.9551
# Epoch 281/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.6285e-06 - accuracy: 1.0000 - val_loss: 0.3179 - val_accuracy: 0.9551
# Epoch 282/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.5788e-06 - accuracy: 1.0000 - val_loss: 0.3184 - val_accuracy: 0.9551
# Epoch 283/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.5306e-06 - accuracy: 1.0000 - val_loss: 0.3192 - val_accuracy: 0.9551
# Epoch 284/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.4866e-06 - accuracy: 1.0000 - val_loss: 0.3197 - val_accuracy: 0.9551
# Epoch 285/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.4460e-06 - accuracy: 1.0000 - val_loss: 0.3201 - val_accuracy: 0.9551
# Epoch 286/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.4002e-06 - accuracy: 1.0000 - val_loss: 0.3206 - val_accuracy: 0.9551
# Epoch 287/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.3609e-06 - accuracy: 1.0000 - val_loss: 0.3214 - val_accuracy: 0.9551
# Epoch 288/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.3205e-06 - accuracy: 1.0000 - val_loss: 0.3220 - val_accuracy: 0.9551
# Epoch 289/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.2802e-06 - accuracy: 1.0000 - val_loss: 0.3227 - val_accuracy: 0.9551
# Epoch 290/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.2428e-06 - accuracy: 1.0000 - val_loss: 0.3231 - val_accuracy: 0.9551
# Epoch 291/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.2088e-06 - accuracy: 1.0000 - val_loss: 0.3237 - val_accuracy: 0.9551
# Epoch 292/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1727e-06 - accuracy: 1.0000 - val_loss: 0.3244 - val_accuracy: 0.9551
# Epoch 293/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1393e-06 - accuracy: 1.0000 - val_loss: 0.3248 - val_accuracy: 0.9551
# Epoch 294/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1063e-06 - accuracy: 1.0000 - val_loss: 0.3254 - val_accuracy: 0.9551
# Epoch 295/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0739e-06 - accuracy: 1.0000 - val_loss: 0.3263 - val_accuracy: 0.9551
# Epoch 296/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0437e-06 - accuracy: 1.0000 - val_loss: 0.3268 - val_accuracy: 0.9551
# Epoch 297/300
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0133e-06 - accuracy: 1.0000 - val_loss: 0.3274 - val_accuracy: 0.9551
# Epoch 298/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.8428e-07 - accuracy: 1.0000 - val_loss: 0.3281 - val_accuracy: 0.9551
# Epoch 299/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.5441e-07 - accuracy: 1.0000 - val_loss: 0.3286 - val_accuracy: 0.9551
# Epoch 300/300
# 56/56 [==============================] - 0s 2ms/step - loss: 9.3003e-07 - accuracy: 1.0000 - val_loss: 0.3292 - val_accuracy: 0.9551

# %% [markdown]
# Once training has finished you can run the following cell to check the training and validation accuracy achieved at the end of each epoch.
#
# **Remember that to pass this assignment your model should achieve a training accuracy of at least 95% and a validation accuracy of at least 90%. If your model didn't achieve these thresholds, try training again with a different model architecture.**

# %%
def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history[f'val_{metric}'])
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, f'val_{metric}'])
    plt.show()
    
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# **If your model passes the previously mentioned thresholds be sure to save your notebook and submit for grading before jumping onto the next section.**

# %% [markdown]
# ## Optional Exercise - Visualizing 3D Vectors
#
# As you saw on the lecture you can visualize the vectors associated with each word in the training set in a 3D space.
#
# For this run the following cells and visit [Tensorflow's Embedding Projector](https://projector.tensorflow.org/).

# %%
# Reverse word index
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# Save the embedding layer
e = model.layers[0]

# Save the weights of the embedding layer
weights = e.get_weights()[0]
print(f"Weights of embedding layer have shape: {weights.shape}")
# Out:
# Weights of embedding layer have shape: (1000, 16)

# %% [markdown]
# ***Expected Output:***
#
# ```
# Weights of embedding layer have shape: (1000, 16)
#
# The above is true if global variables are not modified.
# Notice that this shape will always be (NUM_WORDS, EMBEDDING_DIM).
#
# ```

# %% [markdown]
# Now run the following cell to generate the `vecs.tsv` and `meta.tsv` files that you will upload to the embedding projector.

# %%
# Generate files for embedding visualization
out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for word_num in range(1, NUM_WORDS):
    word = reverse_word_index[word_num]
    embeddings = weights[word_num]
    out_m.write(word + "\n")
    out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

# %% [markdown]
# Before downloading these files be sure to having already submitted your assignment.
#
#
# By running the previous cell, these files are placed within your filesystem. To download them, click on the `Jupyter` logo on the upper-left side of the screen. This will take you to the Jupyter filesystem and there you can download the files by selecting them and clicking on the `Download` button.

# %% [markdown]
# **Congratulations on finishing this week's assignment!**
#
# You have successfully implemented a neural network capable of classifying text and also learned about embeddings and tokenization along the way!
#
# **Keep it up!**
